# %% [markdown]
# # Connectivity

# %%
from blocksnet import City, Connectivity

city = City.from_pickle('../data/model.pickle')
# Out:
# 			<script type="text/javascript">
# 			<!--
#
# 			{
# 				var element = document.getElementById('NetworKit_script');
# 				if (element) {
# 					element.parentNode.removeChild(element);
# 				}
# 				element = document.createElement('script');
# 				element.type = 'text/javascript';
# ...

# %%
connectivity = Connectivity(city_model=city)
result = connectivity.calculate()

# %%
result.head()
# Out:
#                                              geometry  connectivity
# id
# 0   POLYGON ((354918.622 6625258.829, 354901.464 6...          61.7
# 1   POLYGON ((355412.142 6623378.149, 355411.700 6...          64.4
# 2   POLYGON ((353934.329 6625429.433, 353923.453 6...          58.0
# 3   POLYGON ((355099.099 6623847.765, 355074.808 6...          63.8
# 4   POLYGON ((352766.168 6621954.748, 352744.412 6...          64.6

# %%
Connectivity.plot(result, figsize=(10,10))
