# %% [markdown]
# # Diversity

# %%
from blocksnet import City, Diversity

city = City.from_pickle('../data/model.pickle')
# Out:
# 			<script type="text/javascript">
# 			<!--
#
# 			{
# 				var element = document.getElementById('NetworKit_script');
# 				if (element) {
# 					element.parentNode.removeChild(element);
# 				}
# 				element = document.createElement('script');
# 				element.type = 'text/javascript';
# ...

# %%
diversity = Diversity(city_model=city)
result = diversity.calculate()

# %%
result.head()
# Out:
#                                              geometry  diversity
# id
# 0   POLYGON ((354918.622 6625258.829, 354901.464 6...        NaN
# 1   POLYGON ((355412.142 6623378.149, 355411.700 6...        NaN
# 2   POLYGON ((353934.329 6625429.433, 353923.453 6...  -0.000000
# 3   POLYGON ((355099.099 6623847.765, 355074.808 6...   0.693147
# 4   POLYGON ((352766.168 6621954.748, 352744.412 6...   0.693147

# %%
Diversity.plot(result, figsize=(10,10))
