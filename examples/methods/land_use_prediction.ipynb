# %%
from blocksnet import City
city = City.from_pickle('new_model.pickle')

# %%
from blocksnet.method.land_use_prediction.land_use_prediction import LandUsePrediction

lup = LandUsePrediction(city_model=city)

# %%
pred = lup.calculate()
# Out:
# 100%|██████████| 3839/3839 [00:07<00:00, 480.73it/s]

# %%
lup.plot(pred)
