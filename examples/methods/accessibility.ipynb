# %% [markdown]
# # Accessibility

# %%
from blocksnet import City, Accessibility

city = City.from_pickle('../data/model.pickle')

# %%
accessibility = Accessibility(city_model=city)
block = city[123]
result = accessibility.calculate(123)

# %%
result.head()
# Out:
#    id                                           geometry  accessibility_to  \
# 0   0  POLYGON ((354918.622 6625258.829, 354901.464 6...              55.2
# 1   1  POLYGON ((355412.142 6623378.149, 355411.700 6...              59.1
# 2   2  POLYGON ((353934.329 6625429.433, 353923.453 6...              51.3
# 3   3  POLYGON ((355099.099 6623847.765, 355074.808 6...              57.0
# 4   4  POLYGON ((352766.168 6621954.748, 352744.412 6...              61.1
#
#    accessibility_from
# 0                55.6
# 1                58.7
# 2                51.7
# 3                58.1
# 4                58.9

# %%
Accessibility.plot(result, figsize=(10,5))
