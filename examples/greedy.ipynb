# %%
import geopandas as gpd
import networkx as nx
import osmnx as ox
import shapely
import folium

# %% [markdown]
# Инициализация сетевой модели. Загрузка геослоя с площадями и слоя с домами в класс

# %%
OPM_path = '/Users/mvin/Desktop/mp_dev/public_space/DATA/potential_ps.geojson'
house_path = '/Users/mvin/Desktop/mp_dev/public_space/DATA/House_vas.geojson'

# %%
model = network_model.NetworkModel(OPM_path=OPM_path, house_path=house_path)
model.OPM
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pygeos/io.py:89: UserWarning: The shapely GEOS version (3.11.2-CAPI-1.17.2) is incompatible with the PyGEOS GEOS version (3.11.2-CAPI-1.17.2). Conversions between both will be slow
#   warnings.warn(
#         id area_type    Тип Городская функция functional_type          area  \
# 0     1057     large    NaN               NaN                  17921.770684
# 1      229    medium    NaN               NaN                    695.402998
# 2      230     small    NaN               NaN                    219.378711
# 3      231     small    NaN               NaN                    391.590199
# 4      260     large    NaN               NaN                   1493.532095
# ..     ...       ...    ...               ...             ...           ...
# 367  14485     large    сад           Природа                  27483.440998
# 368  14486     large    сад           Природа                  28465.425935
# 369  14498     large    сад           Природа                  47407.178823
# 370  14550     large    сад           Природа                  16136.024783
# 371  14595     large  сквер           Природа                  25190.627339
#
#             exists                                           geometry
# 0    потенциальное  POLYGON ((30.23315 59.94747, 30.23367 59.94741...
# 1    потенциальное  POLYGON ((30.24831 59.95139, 30.24836 59.95127...
# 2    потенциальное  POLYGON ((30.24827 59.95094, 30.24819 59.95092...
# 3    потенциальное  POLYGON ((30.24856 59.95075, 30.24859 59.95065...
# 4    потенциальное  POLYGON ((30.23038 59.94712, 30.23047 59.94711...
# ..             ...                                                ...
# 367  потенциальное  POLYGON ((30.23906 59.92695, 30.23900 59.92697...
# 368  потенциальное  POLYGON ((30.24095 59.93385, 30.24256 59.93398...
# 369  потенциальное  POLYGON ((30.25417 59.93587, 30.25499 59.93610...
# 370  потенциальное  POLYGON ((30.28828 59.93796, 30.28825 59.93799...
# 371  потенциальное  POLYGON ((30.22041 59.93840, 30.22012 59.93843...
#
# [372 rows x 8 columns]

# %% [markdown]
# Поиск и классификация зеленых зон

# %%
# model.find_exist('/Users/mvin/Desktop/mp_dev/public_space/DATA/service.geojson')
# model.OPM

# %%
model.OPM[model.OPM['functional_type'] != '']
# Out:
# Empty GeoDataFrame
# Columns: [id, area_type, Тип, Городская функция, functional_type, area, exists, geometry]
# Index: []

# %% [markdown]
# Вызов метода для построения изохрон. На вход подается граф пешей доступности

# %%
model.create_isochrones('/Users/mvin/Desktop/mp_dev/public_space/DATA/walk_graph_spb_32636.graphml')
model.iso_5
# Out:
#         id area_type    Тип Городская функция functional_type          area  \
# 0     1057     large    NaN               NaN                  17921.770684
# 1      229    medium    NaN               NaN                    695.402998
# 2      230     small    NaN               NaN                    219.378711
# 3      231     small    NaN               NaN                    391.590199
# 4      260     large    NaN               NaN                   1493.532095
# ..     ...       ...    ...               ...             ...           ...
# 367  14485     large    сад           Природа                  27483.440998
# 368  14486     large    сад           Природа                  28465.425935
# 369  14498     large    сад           Природа                  47407.178823
# 370  14550     large    сад           Природа                  16136.024783
# 371  14595     large  сквер           Природа                  25190.627339
#
#             exists                                           geometry    node
# 0    потенциальное  POLYGON ((30.23153 59.94345, 30.23047 59.94609...  189910
# 1    потенциальное  POLYGON ((30.24866 59.95032, 30.24764 59.95080...  271455
# 2    потенциальное  POLYGON ((30.24750 59.95012, 30.24612 59.95148...  236215
# 3    потенциальное  POLYGON ((30.24824 59.95013, 30.24796 59.95014...  274763
# 4    потенциальное  POLYGON ((30.22980 59.94480, 30.22926 59.94488...   50616
# ..             ...                                                ...     ...
# 367  потенциальное  POLYGON ((30.23897 59.92697, 30.23705 59.92956...   17693
# 368  потенциальное  POLYGON ((30.24194 59.93193, 30.24112 59.93345...   17573
# 369  потенциальное  POLYGON ((30.25821 59.93234, 30.25259 59.93289...   17616
# 370  потенциальное  POLYGON ((30.28879 59.93749, 30.28801 59.93791...  166699
# 371  потенциальное  POLYGON ((30.22122 59.93862, 30.22018 59.93873...   69974
#
# [372 rows x 9 columns]

# %% [markdown]
# Создание графа

# %%
g = model.create_graph()
g

# %%
# g.nodes(data=True)

# %%
# model.OPM_info()
# model.provision_info()

# %% [markdown]
# выбор одного оптимального места для ОПМ заданного размера и функционального типа, без открытия ОПМ в этом месте

# %%
# a = model.best_location1('Событийное', 'medium')
# print(f'id пространства: {a[1]}')
# g.nodes[a[1]]

# %%
max_public_spaces = 60

# %% [markdown]
# Вызов функций для нахождения полного решения. Сначала вызывается метод full_solution(), далее - local_search() для улучшения получившегося решения

# %%
model.full_solution(max_public_spaces)

# %%
# model.local_search()

# %%
model.OPM_info()
model.provision_info()
# 4375
# Out:
# количество Многофункциональных ОП: 13
# количество Событийных ОП: 14
# количество Спортивных ОП: 14
# количество Учебных ОП: 15
# общее количество ОП: 56
# количество домов, обеспеченных многофункциональным типом: 1114
# количество домов, обеспеченных событийным типом: 1084
# количество домов, обеспеченных спортивным типом: 987
# количество домов, обеспеченных учебным типом: 926
# количество полностью обеспеченных домов: 900, общее количество домов: 1140
# Среднее время пути от домов до ОП 14.22 минуты

# %% [markdown]
# Рекомендательная функция

# %%
model.recommend_services('Многофункциональное', 200)
# Out:
# 'Игровые зоны, Зелёные зоны, Общественный туалет, Музыкальное пространство, Учебная зона'

# %%
opm = model.geo()
house = model.get_houses()
# Out:
# /Users/mvin/Desktop/mp_dev/public_space/network_model.py:568: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.OPM['functional_type'][indx] = self.graph.nodes[n]['functional_type']
# /Users/mvin/Desktop/mp_dev/public_space/network_model.py:574: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   opm['ratio'][i] = self.get_ratio(row['functional_type'], row['area'])
# /Users/mvin/Desktop/mp_dev/public_space/network_model.py:576: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   opm['services'][i] = self.recommend_services(row['functional_type'], row['area'])
# /Users/mvin/Desktop/mp_dev/public_space/network_model.py:591: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.house['provision_ev'][indx] = self.graph.nodes[n]['provision_ev']
# /Users/mvin/Desktop/mp_dev/public_space/network_model.py:592: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.house['provision_mf'][indx] = self.graph.nodes[n]['provision_mf']
# /Users/mvin/Desktop/mp_dev/public_space/network_model.py:593: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.house['provision_ed'][indx] = self.graph.nodes[n]['provision_ed']
# /Users/mvin/Desktop/mp_dev/public_space/network_model.py:594: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.house['provision_sp'][indx] = self.graph.nodes[n]['provision_sp']
# /Users/mvin/Desktop/mp_dev/public_space/network_model.py:595: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.house['provision'][indx] = self.graph.nodes[n]['provision']

# %%
#h.to_file('house_0.geojson', driver = 'GeoJSON')

# %%
#opm.to_file('opm.geojson', driver='GeoJSON')

# %%
m = folium.Map(location=[59.938732, 30.316229], zoom_start=10, tiles='CartoDB positron')

for i, r in opm.iterrows():
  sim_geo = gpd.GeoSeries(r['geometry']).simplify(tolerance=0.001)
  geo_j = sim_geo.to_json()
  if r['functional_type'] == 'Многофункциональное':
    geo_j = folium.GeoJson(data=geo_j,
                          style_function=lambda x: {'fillColor': 'blue'})
  if r['functional_type'] == 'Событийное':
    geo_j = folium.GeoJson(data=geo_j,
                          style_function=lambda x: {'fillColor': 'red', 'color': 'red'})
  if r['functional_type'] == 'Спортивное':
    geo_j = folium.GeoJson(data=geo_j,
                          style_function=lambda x: {'fillColor': 'green', 'color': 'green'})
  if r['functional_type'] == 'Учебное':
    geo_j = folium.GeoJson(data=geo_j,
                          style_function=lambda x: {'fillColor': 'yellow', 'color': 'yellow'})
  folium.Popup(r['ratio']).add_to(geo_j)
  geo_j.add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_36ab5884b1a3eddb05e1ec60ff112fa0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_36ab5884b1a3eddb05e1ec60ff112fa0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_36ab5884b1a3eddb05e1ec60ff112fa0 = L.map(
#                 &quot;map_36ab5884b1a3eddb05e1ec60ff112fa0&quot;,
#                 {
#                     center: [59.938732, 30.316229],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d5ae65cb40450c235a1f92c678b89a36 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_36ab5884b1a3eddb05e1ec60ff112fa0);
#
#
#         function geo_json_a0920142b591d46ca535082b9f269bce_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillColor&quot;: &quot;blue&quot;};
#             }
#         }
#
#         function geo_json_a0920142b591d46ca535082b9f269bce_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_a0920142b591d46ca535082b9f269bce = L.geoJson(null, {
#                 onEachFeature: geo_json_a0920142b591d46ca535082b9f269bce_onEachFeature,
#
#                 style: geo_json_a0920142b591d46ca535082b9f269bce_styler,
#         });
#
#         function geo_json_a0920142b591d46ca535082b9f269bce_add (data) {
#             geo_json_a0920142b591d46ca535082b9f269bce
#                 .addData(data)
#                 .addTo(map_36ab5884b1a3eddb05e1ec60ff112fa0);
#         }
#             geo_json_a0920142b591d46ca535082b9f269bce_add({&quot;bbox&quot;: [30.23160741908857, 59.946718668356986, 30.237156076780675, 59.947468], &quot;features&quot;: [{&quot;bbox&quot;: [30.23160741908857, 59.946718668356986, 30.237156076780675, 59.947468], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[30.23315, 59.947468], [30.235235810699077, 59.947260086165976], [30.237156076780675, 59.946718668356986], [30.23160741908857, 59.947224844359916], [30.23315, 59.947468]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#         var popup_f7834291d35f31ab1730cbe2491f6b1d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_19303cace63065bc590c3dea4e83f55c = $(`&lt;div id=&quot;html_19303cace63065bc590c3dea4e83f55c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Отдых и общение: 9498.54 м^2, Обслуживание базовых потребностей: 896.09 м^2, Событийная: 1792.18 м^2, Спортивная: 3046.7 м^2, Учебная: 2688.27 м^2&lt;/div&gt;`)[0];
#                 popup_f7834291d35f31ab1730cbe2491f6b1d.setContent(html_19303cace63065bc590c3dea4e83f55c);
#
#
#
#         geo_json_a0920142b591d46ca535082b9f269bce.bindPopup(popup_f7834291d35f31ab1730cbe2491f6b1d)
#         ;
#
#
#
#
#         function geo_json_90c4f9806051a7039fba0959a2ea80c5_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;green&quot;, &quot;fillColor&quot;: &quot;green&quot;};
#             }
#         }
#
#         function geo_json_90c4f9806051a7039fba0959a2ea80c5_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_90c4f9806051a7039fba0959a2ea80c5 = L.geoJson(null, {
#                 onEachFeature: geo_json_90c4f9806051a7039fba0959a2ea80c5_onEachFeature,
#
#                 style: geo_json_90c4f9806051a7039fba0959a2ea80c5_styler,
#         });
#
#         function geo_json_90c4f9806051a7039fba0959a2ea80c5_add (data) {
#             geo_json_90c4f9806051a7039fba0959a2ea80c5
#                 .addData(data)
#                 .addTo(map_36ab5884b1a3eddb05e1ec60ff112fa0);
#         }
#             geo_json_90c4f9806051a7039fba0959a2ea80c5_add({&quot;bbox&quot;: [30.2669657, 59.9260584711084, 30.2688881, 59.92799859999998], &quot;features&quot;: [{&quot;bbox&quot;: [30.2669657, 59.9260584711084, 30.2688881, 59.92799859999998], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[30.2669657, 59.926715299999984], [30.2676854, 59.926282], [30.2688881, 59.92799859999998], [30.267840883764862, 59.9260584711084], [30.2669657, 59.926715299999984]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#         var popup_e6217504e394d6b0ec0af6a3069501aa = L.popup(
