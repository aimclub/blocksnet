# %%
import geopandas as gpd

blocks_gdf = gpd.read_parquet('./../data/blocks.parquet')
blocks_gdf.head()
# Out:
#                                              geometry     land_use  is_living  \
# id
# 0   POLYGON ((354918.622 6625258.829, 354901.464 6...         None       True
# 1   POLYGON ((355412.142 6623378.149, 355411.700 6...    transport       True
# 2   POLYGON ((353934.329 6625429.433, 353923.453 6...   recreation       True
# 3   POLYGON ((355099.099 6623847.765, 355074.808 6...  residential       True
# 4   POLYGON ((352766.168 6621954.748, 352744.412 6...   recreation       True
#
#     build_floor_area  living_demand    living_area  share_living  \
# id
# 0       43840.686518      50.641057   30688.480678      2.199357
# 1       10294.395525      53.114392    2177.690063      0.431105
# 2        1173.871643      58.693582     821.710142      0.706252
# 3       46303.954706      52.660044   30595.485797      2.760046
# 4      153749.574111      53.097680  106407.750936      2.352959
#
#     business_area  share_business     site_area  ...  capacity_bus_station  \
# ...

# %% [markdown]
# ## Spacematrix indicators

# %%
from blocksnet.analysis.indicators import calculate_spacematrix_indicators 

blocks_df = calculate_spacematrix_indicators(blocks_gdf[[
    'site_area',
    'footprint_area',
    'build_floor_area',
    'living_area'
]])
# Out:
# 2025-03-26 20:24:22.465 | WARNING  | blocksnet.analysis.indicators.spacematrix.core:_restore_non_living_area:19 - The non_living_area is not in columns, restoring

# %%
blocks_df.head()
# Out:
#        site_area  footprint_area  build_floor_area    living_area  \
# id
# 0   8.044667e+05    13953.390266      43840.686518   30688.480678
# 1   2.317313e+04     5051.410558      10294.395525    2177.690063
# 2   3.630058e+05     1163.480697       1173.871643     821.710142
# 3   1.964145e+05    11085.135352      46303.954706   30595.485797
# 4   1.781752e+06    45222.959595     153749.574111  106407.750936
#
#     non_living_area       fsi       gsi       mxi         l         osr  \
# id
# 0      13152.205840  0.054497  0.017345  0.700000  3.141938   18.031500
# 1       8116.705462  0.444238  0.217986  0.211541  2.037925    1.760348
# 2        352.161501  0.003234  0.003205  0.700000  1.008931  308.246934
# 3      15708.468909  0.235746  0.056437  0.660753  4.177121    4.002452
# 4      47341.823175  0.086291  0.025381  0.692085  3.399812   11.294526
#
#     share_business  share_living
# id
# 0         0.942581      2.199357
# 1         1.606820      0.431105
# ...

# %% [markdown]
# ## Development indicators

# %%
blocks_gdf = blocks_gdf[blocks_gdf.fsi >= blocks_gdf.gsi]

# %%
from blocksnet.analysis.indicators import calculate_development_indicators 

blocks_df = calculate_development_indicators(blocks_gdf[[
    'site_area',
    'fsi',
    'gsi',
    'mxi',
]])

# %%
blocks_df.head()
# Out:
#        site_area       fsi       gsi       mxi  build_floor_area  \
# id
# 0   8.044667e+05  0.054497  0.017345  0.700000      43840.686518
# 1   2.317313e+04  0.444238  0.217986  0.211541      10294.395525
# 2   3.630058e+05  0.003234  0.003205  0.700000       1173.871643
# 3   1.964145e+05  0.235746  0.056437  0.660753      46303.954706
# 4   1.781752e+06  0.086291  0.025381  0.692085     153749.574111
#
#     footprint_area    living_area  non_living_area
# id
# 0     13953.390266   30688.480678     13152.205840
# 1      5051.410558    2177.690063      8116.705462
# 2      1163.480697     821.710142       352.161501
# 3     11085.135352   30595.485797     15708.468909
# 4     45222.959595  106407.750936     47341.823175
